# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import glob
import re

# Set style for matplotlib plots
plt.style.use('classic') 
# Set style for matplotlib plots
plt.style.use('classic')   

#Data Inputs

# Find all file names of the files to be imported
filenames = glob.glob('Exercise 6B Data/Input Data/*.txt')

# Create an empty dataframe
df_plate_bendingmoment = pd.DataFrame()

# Loop through all filenames and append the data to the dataframe
for file in filenames:
    # Get the name of the stage from the filename
    stage_name = re.search('Plate_ (.*?) \(', file).group(1)

    # Import txt file to a temporary dataframe
    # <Code here!>
    dftemp = pd.read_csv(file, sep= '\t')
    # Create a new column in the temporary dataframe to store the stage name
    # <Code here!>
    dftemp['stage_name']  = stage_name
    # Append the temporary dataframe to the dataframe
    # <Code here!>
    df_plate_bendingmoment = dftemp.append(dftemp, ignore_index= True)
# Inspect the column names and rename them if necessary
# <Code here!>
df_plate_bendingmoment.columns = ['Structural element', 'Node', 'Local number', 'x [m]', 'y [m]', 'N [kN/m]', 'N_min [kN/m]', 
                                 'N_max [kN/m]', 'Q [kN/m]', 'Q_min [kN/m]', 'Q_max [kN/m]', 'M [kN m/m]', 'M_min [kN m/m]', 'M_max [kN m/m]', 'stage_name']

    
# Inspect the dataframes and check for the number of rows in the dataframe (there are supposed to be 2570 rows)
display(len(df_plate_bendingmoment))
# <Code here!>
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_12092\2242193860.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_plate_bendingmoment = dftemp.append(dftemp, ignore_index= True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_12092\2242193860.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_plate_bendingmoment = dftemp.append(dftemp, ignore_index= True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_12092\2242193860.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_plate_bendingmoment = dftemp.append(dftemp, ignore_index= True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_12092\2242193860.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_plate_bendingmoment = dftemp.append(dftemp, ignore_index= True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_12092\2242193860.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_plate_bendingmoment = dftemp.append(dftemp, ignore_index= True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_12092\2242193860.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_plate_bendingmoment = dftemp.append(dftemp, ignore_index= True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_12092\2242193860.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_plate_bendingmoment = dftemp.append(dftemp, ignore_index= True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_12092\2242193860.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_plate_bendingmoment = dftemp.append(dftemp, ignore_index= True)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_12092\2242193860.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_plate_bendingmoment = dftemp.append(dftemp, ignore_index= True)
# 660

# %%
df_plate_bendingmoment
# Out:
#          Structural element   Node  Local number                   x [m]  \
# 0               Plate\_1\_1    481             1  -7,50000000000000E+000
# 1       Element 1-1 (Plate)    480             2  -7,50000000000000E+000
# 2                    (ERSS)    479             3  -7,50000000000000E+000
# 3                              478             4  -7,50000000000000E+000
# 4                              482             5  -7,50000000000000E+000
# ..                      ...    ...           ...                     ...
# 655            Plate\_2\_16  16420             1   7,50000000000000E+000
# 656  Element 51-104 (Plate)  16421             2   7,50000000000000E+000
# 657                  (ERSS)  16422             3   7,50000000000000E+000
# 658                          16423             4   7,50000000000000E+000
# 659                          17112             5   7,50000000000000E+000
#
#                       y [m]                N [kN/m]            N_min [kN/m]  \
# 0     2,85000000000000E+000   1,11495357553799E+000  -8,04530658812172E-001
# 1     2,51250000000000E+000  -4,27103114666345E+000  -5,26598259238743E+000
# 2     2,17500000000000E+000  -1,00228490948123E+001  -1,07781219452398E+001
# 3     1,83750000000000E+000  -1,59103004559774E+001  -1,60742400549903E+001
# 4     1,50000000000000E+000  -2,17031854172276E+001  -2,19017268506884E+001
# ..                      ...                     ...                     ...
# 655  -1,70000000000000E+001   3,27981383124226E+001  -1,41650066483771E+001
# 656  -1,71250000000000E+001   3,01611600135459E+001  -1,32005205654724E+001
# 657  -1,72500000000000E+001   2,74400146055249E+001  -1,22280703064271E+001
# 658  -1,73750000000000E+001   2,46662638040851E+001  -1,12605425046879E+001
# 659  -1,75000000000000E+001   2,18714693249523E+001  -1,03108237937016E+001
#
#               N_max [kN/m]                Q [kN/m]            Q_min [kN/m]  \
# 0    1,11892218795259E+000   2,86540681357623E+000  -9,36710463384537E-002
# 1    5,86208363179141E-005  -1,02800208217154E+001  -1,26420993915753E+001
# 2    3,29549126897870E-005  -2,54697198945692E+001  -2,70787179956065E+001
# 3    1,74607721085982E-005  -4,21117180781545E+001  -4,21117180781545E+001
# 4    1,52355267939873E-005  -5,96140430456405E+001  -5,96140430456405E+001
# ..                     ...                     ...                     ...
# 655  3,62226451009570E+001   5,80049424997968E+000  -2,13396549159882E-001
# 656  3,33105039672409E+001   7,97447710680737E+000  -2,25576009279377E-001
# 657  3,03136302105300E+001   8,81817310898082E+000  -2,16505072605661E-001
# 658  2,72667069710127E+001   8,45382333720824E+000  -1,84514653907125E-001
# 659  2,42044173888772E+001   7,00366887219787E+000  -1,27935667952156E-001
#
#               Q_max [kN/m]              M [kN m/m]          M_min [kN m/m]  \
# 0    2,89271215493922E+000  -2,52575738102223E-014  -6,30523411260242E-013
# 1    1,69367103826703E+000  -1,17574436794718E+000  -1,70306000874940E+000
# 2    2,47531139895095E+000  -7,18218681643449E+000  -8,39232268638222E+000
# 3    2,57518838288977E+000  -1,85350742721976E+001  -1,99423730927473E+001
# 4    2,52169863006703E+000  -3,56910171354729E+001  -3,62762473975197E+001
# ..                     ...                     ...                     ...
# 655  6,04713477179159E+000  -4,00645821169241E+000  -4,17833003716256E+000
# 656  8,31573861193837E+000  -3,13059021727124E+000  -3,26505019812834E+000
# 657  9,19602495408978E+000  -2,06910301377388E+000  -2,15812477728820E+000
# 658  8,81709642235490E+000  -9,75845611525455E-001  -1,01795169870103E+000
# 659  7,30805564084282E+000  -3,26128013483640E-014  -3,86836396248924E-013
#
#             M_max [kN m/m]                 stage_name
# 0    3,66623398306842E-013  Cast Base Slab [Phase_10]
# 1    3,13423271299049E-001  Cast Base Slab [Phase_10]
# 2    1,03419525045104E+000  Cast Base Slab [Phase_10]
# 3    1,90081049994095E+000  Cast Base Slab [Phase_10]
# 4    2,68589307815659E+000  Cast Base Slab [Phase_10]
# ..                     ...                        ...
# 655  1,00613725535806E-001  Cast Base Slab [Phase_10]
# 656  7,29810373594294E-002  Cast Base Slab [Phase_10]
# 657  4,50936254449283E-002  Cast Base Slab [Phase_10]
# 658  1,97967248085417E-002  Cast Base Slab [Phase_10]
# 659  5,13492026676943E-013  Cast Base Slab [Phase_10]
#
# [660 rows x 15 columns]
