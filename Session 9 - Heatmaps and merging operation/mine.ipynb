# %%
import pandas as pd

# Creata a dummy dataframe
df = pd.DataFrame({
    'x': [1, 1, 1, 2, 2, 2, 3, 3, 3],
    'y': ['a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c'],
    'values': [34, 74, 1, 9, -36, -24, 47, -27, 47]})

# Pivot the dataframe
df_pivot = df.pivot(index='y', columns='x', values='values')
df_pivot
import seaborn as sns

# Plot the pivotted dataframe as a heatmap
sns.heatmap(df_pivot, annot=True,square=True, cmap= 'Reds',vmax=80,vmin=-40,cbar_kws={"orientation": "vertical"})
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
import pandas as pd
import seaborn as sns
df = pd.read_csv('Crack_width_Seg7_y_direction.csv')
df2 = df[df['Criterion']== 'max My']
df3 = df2.pivot(index='y[m]', columns= 'x[m]', values= 'w_k[mm]')
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.heatmap(df3,annot= True,annot_kws={'size': 6},fmt= '.2f', cmap= 'hsv' )
# Out:
# <Axes: xlabel='x[m]', ylabel='y[m]'>
